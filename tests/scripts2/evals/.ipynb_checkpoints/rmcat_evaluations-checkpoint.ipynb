# %%
#Plotting 
def plot_snd_throughputs(owd, container, duration, range_, flownum, labels, legends, pdf_num, veth_str) :
    
    range_str       = str(range_)
    duration_str    = str(duration)
    flownum_str     = str(flownum)
    pdf_num_str     = str(pdf_num)
    
    throughput_file = "../saves/" + container + "/" + veth_str + "_owd"  + str(owd) + "_" + pdf_num_str + ".csv"
    plot_file       = "../gnuplots/snd_throughputs.plot"
    output          = "../saves/" + container + "/pdfs/" + veth_str + "_owd" + str(owd) + "_" + pdf_num_str + ".pdf"

    if(labels and legends) :
        # !gnuplot -e "labels='1'" -e "legends='1'" -e "output_file='$output'" -e "throughput_file='$throughput_file'" -e "range='$range_str'" -e "flownum='$flownum_str'" -e "duration='$duration_str'" $plot_file
    elif(labels) : 
        # !gnuplot -e "labels='1'" -e "output_file='$output'" -e "throughput_file='$throughput_file'" -e "range='$range_str'" -e "flownum='$flownum_str'" -e "duration='$duration_str'" $plot_file
    elif(legends) : 
        # !gnuplot -e "legends='1'" -e "output_file='$output'" -e "throughput_file='$throughput_file'" -e "range='$range_str'" -e "flownum='$flownum_str'" -e "duration='$duration_str'" $plot_file
    else : 
        # !gnuplot -e "output_file='$output'" -e "throughput_file='$throughput_file'" -e "range='$range_str'" -e "flownum='$flownum_str'" -e "duration='$duration_str'" $plot_file

# %%
from shutil import copyfile
import os.path
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

#range_ = 1200
#owd = 100
#container = "rmcat1"
def eval_measurements(owd, container, time_range_):
    save_directory    = "../saves/"+container+"/csv/"
    owd_str           = "owd" + str(owd)
    columns = ['sender_rate','fec_rate','capacity']
    alldf = pd.DataFrame(columns=columns)
    alldf = alldf.fillna(0) # with 0s rather than NaNs
    for x in range(0, 9):
        csv_file = save_directory + "veth_stats_" + owd_str + "_" + str(x) + ".csv"
        if(os.path.isfile(csv_file) == False) :
            print('Missing file: {}'.format(csv_file))
            continue

        df = pd.read_csv(csv_file, names=columns)
        alldf = pd.concat([alldf, df[:time_range_]])
    
    print("\nAverages\n" + str(alldf.mean()))
    print("\nStandard deviations\n" + str(alldf.std()))

# %%
from shutil import copyfile
import os.path

def save_measurement(owd, container, counter) :
    
    save_directory    = "../saves/"+container+"/csv/"
    owd_str           = "owd" + str(owd)
    veths             = ["veth0_stats","veth3_stats"]
    
    for veth in veths : 
        src_file = veth + ".csv"
        dst_file = veth + "_" + owd_str + "_" + str(counter) + ".csv"
        src_path = "../temp/" + src_file
        dst_path = save_directory + dst_file
        copyfile(src_path, dst_path)

# %%
#RMCAT1 Test

container = "rmcat1"
veth0_str = "veth0_stats"
duration  = 120
range_    = 3000
flownum   = 1

range_bgn = 3
range_end = 4
plays     = [0,1,0] 

owds      = [50,150,300]
labels    = [True,False,False]
legends   = [False,False,True]

for x in range(0,3) :
    
    if(plays[x] == 0) :
        continue;
        
    owd    = owds[x]
    label  = labels[x]
    legend = legends[x]
    
    for y in range(range_bgn, range_end):
        # !cd ..;cd ..; scripts2/runs/rmcat1.sh -s $owd 
        save_measurement(owd, container, y)
        plot_snd_throughputs(owd, container, duration, range_, flownum, label, legend, y, veth0_str)
    
    eval_measurements(owd, container, duration * 10)
# Out:
# [INFO] Constructing NTRT system machine.
# [INFO] NTRT system machine is constructed
# [INFO] Constructing Managed datamap.
# [INFO] Managed datamap is constructed
# [INFO] FSM: Setup event is fired, actual state is Halt
# [INFO] Constructing PCAP Sniffer component.
# [INFO] PCAP Sniffer component is constructed
# [INFO] Constructing Sniff Evaluator component.
# [INFO] Sniff Evaluator component is constructed
# [INFO] Constructing Records Recycle component.
# [INFO] Records Recycle component is constructed
# [INFO] Constructing Recorder component.
# [INFO] Recorder component is constructed
# [INFO] Constructing Records relayer component.
# [INFO] Records relayer component is constructed
# [INFO] Constructing Record Accumulator component.
# [INFO] Record Accumulator component is constructed
# [INFO] Constructing Command File Executor component.
# [INFO] Command File Executor component is constructed
# [INFO] Feature IP_PACKETS                          is installed
# [INFO] Feature IP_BYTES                            is installed
# [INFO] Feature TCP_PACKETS                         is installed
# [INFO] Feature TCP_BYTES                           is installed
# [INFO] Feature UDP_PACKETS                         is installed
# [INFO] Feature UDP_BYTES                           is installed
# [INFO] Feature RTP_PACKETS_X                       is installed
# [INFO] Feature RTP_BYTES_X                         is installed
# [INFO] Feature LOST_RTP_PACKETS_X                  is installed
# [INFO] Feature SRC_UDP_PACKETS_X                   is installed
# [INFO] Feature SRC_UDP_BYTES_X                     is installed
# [INFO] Feature SRC_TCP_PACKETS_X                   is installed
# [INFO] Feature SRC_TCP_BYTES_X                     is installed
# [INFO] Feature SRC_RTP_PACKETS_X_Y                 is installed
# [INFO] Feature SRC_RTP_BYTES_X_Y                   is installed
# [INFO] Feature SRC_LOST_RTP_PACKETS_X_Y            is installed
# [INFO] Feature DST_UDP_PACKETS_X                   is installed
# [INFO] Feature DST_UDP_BYTES_X                     is installed
# [INFO] Feature DST_TCP_PACKETS_X                   is installed
# [INFO] Feature DST_TCP_BYTES_X                     is installed
# [INFO] Feature DST_RTP_PACKETS_X_Y                 is installed
# [INFO] Feature DST_RTP_BYTES_X_Y                   is installed
# [INFO] Feature DST_LOST_RTP_PACKETS_X_Y            is installed
# [INFO] Add pcap listener. (device: veth3), (feature_num: 9), (pcap_filter: )
# [INFO] Feature DST_UDP_BYTES_5000 is added listening for device veth3
# [INFO] Feature DST_UDP_PACKETS_5000 is added listening for device veth3
# [INFO] Feature DST_LOST_RTP_PACKETS_5000_96 is added listening for device veth3
# [INFO] Feature DST_UDP_BYTES_5016 is added listening for device veth3
# [INFO] Feature DST_UDP_PACKETS_5016 is added listening for device veth3
# [INFO] Feature DST_LOST_RTP_PACKETS_5016_96 is added listening for device veth3
# [INFO] Feature DST_UDP_BYTES_5030 is added listening for device veth3
# [INFO] Feature DST_UDP_PACKETS_5030 is added listening for device veth3
# [INFO] Feature DST_LOST_RTP_PACKETS_5030_96 is added listening for device veth3
# [INFO] Mapped var with id 1 is successfully addded to DMAP
# [INFO] FSM: Transitions performed, the actual state is Halt
# [INFO] FSM: Start event is fired, actual state is Halt
# [INFO] Start Records relayer component
# [INFO] Constructing Records relayer component.
# [WARN] (errno: None) Records relayer component is already constructed
# [INFO] Records relayer component is started.
# [INFO] Start PCAP Listener component
# [INFO] Constructing PCAP Listener component.
# [INFO] PCAP Listener component is constructed
# [INFO] PCAP Listener component is started.
# [INFO] FSM: Transitions performed, the actual state is Run
# [INFO] NTRT is going to be terminated 150 sec later
# [INFO] Pcap filter is set to device: veth3
# Joining session 0x23baa60
# Connecting to 5000/5001/5005/5011/5012/5010
# New pad: recv_rtp_sink_0, looking for recv_rtp_src_0_*
# New pad: recv_rtcp_sink_0, looking for recv_rtp_src_0_*
# New pad: send_rtcp_src_0, looking for recv_rtp_src_0_*
# starting client pipeline
# Pipeline pipeline0 changed state from NULL to READY
# Pipeline pipeline0 changed state from READY to PAUSED
# Pipeline pipeline0 changed state from PAUSED to PLAYING
# [INFO] Constructing NTRT system machine.
# [INFO] NTRT system machine is constructed
# [INFO] Constructing Managed datamap.
# [INFO] Managed datamap is constructed
# [INFO] FSM: Setup event is fired, actual state is Halt
# [INFO] Constructing PCAP Sniffer component.
# [INFO] PCAP Sniffer component is constructed
# [INFO] Constructing Sniff Evaluator component.
# [INFO] Sniff Evaluator component is constructed
# [INFO] Constructing Records Recycle component.
# [INFO] Records Recycle component is constructed
# [INFO] Constructing Recorder component.
# [INFO] Recorder component is constructed
# [INFO] Constructing Records relayer component.
# [INFO] Records relayer component is constructed
# [INFO] Constructing Record Accumulator component.
# [INFO] Record Accumulator component is constructed
# [INFO] Constructing Command File Executor component.
# [INFO] Command File Executor component is constructed
# [INFO] Feature IP_PACKETS                          is installed
# [INFO] Feature IP_BYTES                            is installed
# [INFO] Feature TCP_PACKETS                         is installed
# [INFO] Feature TCP_BYTES                           is installed
# [INFO] Feature UDP_PACKETS                         is installed
# [INFO] Feature UDP_BYTES                           is installed
# [INFO] Feature RTP_PACKETS_X                       is installed
# [INFO] Feature RTP_BYTES_X                         is installed
# [INFO] Feature LOST_RTP_PACKETS_X                  is installed
# [INFO] Feature SRC_UDP_PACKETS_X                   is installed
# [INFO] Feature SRC_UDP_BYTES_X                     is installed
# [INFO] Feature SRC_TCP_PACKETS_X                   is installed
# [INFO] Feature SRC_TCP_BYTES_X                     is installed
# [INFO] Feature SRC_RTP_PACKETS_X_Y                 is installed
# [INFO] Feature SRC_RTP_BYTES_X_Y                   is installed
# [INFO] Feature SRC_LOST_RTP_PACKETS_X_Y            is installed
# [INFO] Feature DST_UDP_PACKETS_X                   is installed
# [INFO] Feature DST_UDP_BYTES_X                     is installed
# [INFO] Feature DST_TCP_PACKETS_X                   is installed
# [INFO] Feature DST_TCP_BYTES_X                     is installed
# [INFO] Feature DST_RTP_PACKETS_X_Y                 is installed
# [INFO] Feature DST_RTP_BYTES_X_Y                   is installed
# [INFO] Feature DST_LOST_RTP_PACKETS_X_Y            is installed
# [INFO] Add pcap listener. (device: veth0), (feature_num: 6), (pcap_filter: )
# [INFO] Feature DST_RTP_BYTES_5000_96 is added listening for device veth0
# [INFO] Feature DST_RTP_BYTES_5000_126 is added listening for device veth0
# [INFO] Feature DST_RTP_BYTES_5016_96 is added listening for device veth0
# [INFO] Feature DST_RTP_BYTES_5016_126 is added listening for device veth0
# [INFO] Feature DST_RTP_BYTES_5030_96 is added listening for device veth0
# [INFO] Feature DST_RTP_BYTES_5030_126 is added listening for device veth0
# [INFO] Mapped var with id 1 is successfully addded to DMAP
# [INFO] FSM: Transitions performed, the actual state is Halt
# [INFO] FSM: Start event is fired, actual state is Halt
# [INFO] Start Records relayer component
# [INFO] Constructing Records relayer component.
# [WARN] (errno: None) Records relayer component is already constructed
# [INFO] Records relayer component is started.
# [INFO] Start Command Interpreter Component
# [INFO] Constructing Command Interpreter Component.
# [INFO] Command Interpreter Component is constructed
# [INFO] Command Interpreter Component is started.
# [INFO] Start PCAP Listener component
# [INFO] Constructing PCAP Listener component.
# [INFO] PCAP Listener component is constructed
# [INFO] PCAP Listener component is started.
# [INFO] FSM: Transitions performed, the actual state is Run
# [INFO] NTRT is going to be terminated 150 sec later
# [INFO] Executing command O sudo ip netns exec ns_mid tc qdisc change dev veth2 parent 1: handle 2: tbf rate 1000kbit burst 100kbit latency 300ms minburst 1540
#
# [INFO] Pcap filter is set to device: veth0
# join subflow 1
# path: 1
# starting server pipeline
# actual state: 3, pending: 4, changeresult: 2
# Pipeline pipeline0 changed state from NULL to READY
# Pipeline pipeline0 changed state from READY to PAUSED
# [INFO] Executing command I MAPPED_VAR_1_1000
#
# [INFO] Mapped var 1 value changed from 0 to 1000
# Pipeline pipeline0 changed state from PAUSED to PLAYING
# Looking for caps for pt 96 in session 0, have 0
# Returning application/x-rtp, media=(string)video, clock-rate=(int)90000, width=(int)352, height=(int)288, framerate=(fraction)25/1, encoding-name=(string)VP8
# New pad: recv_rtp_src_0_4009012710_96, looking for recv_rtp_src_0_*
# Pipeline pipeline0 changed state from PAUSED to PAUSED
# Linked!
# Pipeline pipeline0 changed state from PAUSED to PAUSED
# Pipeline pipeline0 changed state from PAUSED to PLAYING
# backward congestion fbinterval: 100000000
# [INFO] Executing command O sudo ip netns exec ns_mid tc qdisc change dev veth2 parent 1: handle 2: tbf rate 2500kbit burst 250kbit latency 300ms minburst 1540
#
# [INFO] Executing command I MAPPED_VAR_1_2500
#
# [INFO] Mapped var 1 value changed from 1000 to 2500
# [INFO] Executing command O sudo ip netns exec ns_mid tc qdisc change dev veth2 parent 1: handle 2: tbf rate 600kbit burst 60kbit latency 300ms minburst 1540
#
# [INFO] Executing command I MAPPED_VAR_1_600
#
# [INFO] Mapped var 1 value changed from 2500 to 600
# [INFO] Executing command O sudo ip netns exec ns_mid tc qdisc change dev veth2 parent 1: handle 2: tbf rate 1000kbit burst 100kbit latency 300ms minburst 1540
#
# [INFO] Executing command I MAPPED_VAR_1_1000
#
# [INFO] Mapped var 1 value changed from 600 to 1000
# backward congestion fbinterval: 124999998
# [INFO] Command interpreter is finished with file scripts2/configs/ntrt_rmcat1.cmds
# backward congestion fbinterval: 100000000
# [INFO] FSM: Stop event is fired, actual state is Run
# [INFO] STOP Records relayer component.
# [INFO] Destructing Records relayer component.
# [INFO] Records relayer component is destructed.
# [INFO] Records relayer component is stopped.
# [INFO] STOP PCAP Listener component.
#
# Usage:
#  kill [options] <pid> [...]
#
# Options:
#  <pid> [...]            send signal to every <pid> listed
#  -<signal>, -s, --signal <signal>
#                         specify the <signal> to be sent
#  -l, --list=[<signal>]  list all signal names, or convert one to a name
#  -L, --table            list all signal names in a nice table
#
#  -h, --help     display this help and exit
#  -V, --version  output version information and exit
#
# For more details see kill(1).
# line 76: warning: Cannot find or open file "../saves/rmcat1veth0_stats_owd150_3.csv"
# line 76: warning: Cannot find or open file "../saves/rmcat1veth0_stats_owd150_3.csv"
# line 76: warning: Cannot find or open file "../saves/rmcat1veth0_stats_owd150_3.csv"
# line 76: No data in plot
#
# Missing file: ../saves/rmcat1/csv/veth_stats_owd150_0.csv
# Missing file: ../saves/rmcat1/csv/veth_stats_owd150_1.csv
# Missing file: ../saves/rmcat1/csv/veth_stats_owd150_2.csv
# Missing file: ../saves/rmcat1/csv/veth_stats_owd150_3.csv
# Missing file: ../saves/rmcat1/csv/veth_stats_owd150_4.csv
# Missing file: ../saves/rmcat1/csv/veth_stats_owd150_5.csv
# Missing file: ../saves/rmcat1/csv/veth_stats_owd150_6.csv
# Missing file: ../saves/rmcat1/csv/veth_stats_owd150_7.csv
# Missing file: ../saves/rmcat1/csv/veth_stats_owd150_8.csv
#
# Averages
# sender_rate   NaN
# fec_rate      NaN
# capacity      NaN
# dtype: float64
#
# Standard deviations
# sender_rate   NaN
# fec_rate      NaN
# capacity      NaN
# dtype: float64

# %%
#RMCAT2 Test

container = "rmcat2"
veth0_str = "veth0_stats"
duration  = 140
range_    = 5000
flownum   = 1

range_bgn = 3
range_end = 4
plays     = [0,1,0] 

owds      = [50,150,300]
labels    = [True,False,False]
legends   = [False,False,True]

for x in range(0,3) :
    
    if(plays[x] == 0) :
        continue;
        
    owd    = owds[x]
    label  = labels[x]
    legend = legends[x]
    
    for y in range(range_bgn, range_end):
        # !cd ..;cd ..; scripts2/runs/rmcat2.sh -s $owd 
        save_measurement(owd, container, y)
        plot_snd_throughputs(owd, container, duration, range_, flownum, label, legend, y, veth0_str)
    
    eval_measurements(owd, container, duration * 10)
# Out:
# [INFO] Constructing NTRT system machine.
# [INFO] NTRT system machine is constructed
# [INFO] Constructing Managed datamap.
# [INFO] Managed datamap is constructed
# [INFO] FSM: Setup event is fired, actual state is Halt
# [INFO] Constructing PCAP Sniffer component.
# [INFO] PCAP Sniffer component is constructed
# [INFO] Constructing Sniff Evaluator component.
# [INFO] Sniff Evaluator component is constructed
# [INFO] Constructing Records Recycle component.
# [INFO] Records Recycle component is constructed
# [INFO] Constructing Recorder component.
# [INFO] Recorder component is constructed
# [INFO] Constructing Records relayer component.
# [INFO] Records relayer component is constructed
# [INFO] Constructing Record Accumulator component.
# [INFO] Record Accumulator component is constructed
# [INFO] Constructing Command File Executor component.
# [INFO] Command File Executor component is constructed
# [INFO] Feature IP_PACKETS                          is installed
# [INFO] Feature IP_BYTES                            is installed
# [INFO] Feature TCP_PACKETS                         is installed
# [INFO] Feature TCP_BYTES                           is installed
# [INFO] Feature UDP_PACKETS                         is installed
# [INFO] Feature UDP_BYTES                           is installed
# [INFO] Feature RTP_PACKETS_X                       is installed
# [INFO] Feature RTP_BYTES_X                         is installed
# [INFO] Feature LOST_RTP_PACKETS_X                  is installed
# [INFO] Feature SRC_UDP_PACKETS_X                   is installed
# [INFO] Feature SRC_UDP_BYTES_X                     is installed
# [INFO] Feature SRC_TCP_PACKETS_X                   is installed
# [INFO] Feature SRC_TCP_BYTES_X                     is installed
# [INFO] Feature SRC_RTP_PACKETS_X_Y                 is installed
# [INFO] Feature SRC_RTP_BYTES_X_Y                   is installed
# [INFO] Feature SRC_LOST_RTP_PACKETS_X_Y            is installed
# [INFO] Feature DST_UDP_PACKETS_X                   is installed
# [INFO] Feature DST_UDP_BYTES_X                     is installed
# [INFO] Feature DST_TCP_PACKETS_X                   is installed
# [INFO] Feature DST_TCP_BYTES_X                     is installed
# [INFO] Feature DST_RTP_PACKETS_X_Y                 is installed
# [INFO] Feature DST_RTP_BYTES_X_Y                   is installed
# [INFO] Feature DST_LOST_RTP_PACKETS_X_Y            is installed
# [INFO] Add pcap listener. (device: veth3), (feature_num: 9), (pcap_filter: )
# [INFO] Feature DST_UDP_BYTES_5000 is added listening for device veth3
# [INFO] Feature DST_UDP_PACKETS_5000 is added listening for device veth3
# [INFO] Feature DST_LOST_RTP_PACKETS_5000_96 is added listening for device veth3
# [INFO] Feature DST_UDP_BYTES_5016 is added listening for device veth3
# [INFO] Feature DST_UDP_PACKETS_5016 is added listening for device veth3
# [INFO] Feature DST_LOST_RTP_PACKETS_5016_96 is added listening for device veth3
# [INFO] Feature DST_UDP_BYTES_5030 is added listening for device veth3
# [INFO] Feature DST_UDP_PACKETS_5030 is added listening for device veth3
# [INFO] Feature DST_LOST_RTP_PACKETS_5030_96 is added listening for device veth3
# [INFO] FSM: Transitions performed, the actual state is Halt
# [INFO] FSM: Start event is fired, actual state is Halt
# [INFO] Start Records relayer component
# [INFO] Constructing Records relayer component.
# [WARN] (errno: None) Records relayer component is already constructed
# [INFO] Records relayer component is started.
# [INFO] Start PCAP Listener component
# [INFO] Constructing PCAP Listener component.
# [INFO] PCAP Listener component is constructed
# [INFO] PCAP Listener component is started.
# [INFO] FSM: Transitions performed, the actual state is Run
# [INFO] NTRT is going to be terminated 180 sec later
# [INFO] Pcap filter is set to device: veth3
# Joining session 0x15faa60
# Connecting to 5000/5001/5005/5011/5012/5010
# New pad: recv_rtp_sink_0, looking for recv_rtp_src_0_*
# New pad: recv_rtcp_sink_0, looking for recv_rtp_src_0_*
# New pad: send_rtcp_src_0, looking for recv_rtp_src_0_*
# starting client pipeline
# Pipeline pipeline0 changed state from NULL to READY
# Pipeline pipeline0 changed state from READY to PAUSED
# Pipeline pipeline0 changed state from PAUSED to PLAYING
# Joining session 0xeb67d0
# Connecting to 5000/5001/5005/5011/5012/5010
# New pad: recv_rtp_sink_0, looking for recv_rtp_src_0_*
# New pad: recv_rtcp_sink_0, looking for recv_rtp_src_0_*
# New pad: send_rtcp_src_0, looking for recv_rtp_src_0_*
# starting client pipeline
# Pipeline pipeline0 changed state from NULL to READY
# Pipeline pipeline0 changed state from READY to PAUSED
# Pipeline pipeline0 changed state from PAUSED to PLAYING
# [INFO] Constructing NTRT system machine.
# [INFO] NTRT system machine is constructed
# [INFO] Constructing Managed datamap.
# [INFO] Managed datamap is constructed
# [INFO] FSM: Setup event is fired, actual state is Halt
# [INFO] Constructing PCAP Sniffer component.
# [INFO] PCAP Sniffer component is constructed
# [INFO] Constructing Sniff Evaluator component.
# [INFO] Sniff Evaluator component is constructed
# [INFO] Constructing Records Recycle component.
# [INFO] Records Recycle component is constructed
# [INFO] Constructing Recorder component.
# [INFO] Recorder component is constructed
# [INFO] Constructing Records relayer component.
# [INFO] Records relayer component is constructed
# [INFO] Constructing Record Accumulator component.
# [INFO] Record Accumulator component is constructed
# [INFO] Constructing Command File Executor component.
# [INFO] Command File Executor component is constructed
# [INFO] Feature IP_PACKETS                          is installed
# [INFO] Feature IP_BYTES                            is installed
# [INFO] Feature TCP_PACKETS                         is installed
# [INFO] Feature TCP_BYTES                           is installed
# [INFO] Feature UDP_PACKETS                         is installed
# [INFO] Feature UDP_BYTES                           is installed
# [INFO] Feature RTP_PACKETS_X                       is installed
# [INFO] Feature RTP_BYTES_X                         is installed
# [INFO] Feature LOST_RTP_PACKETS_X                  is installed
# [INFO] Feature SRC_UDP_PACKETS_X                   is installed
# [INFO] Feature SRC_UDP_BYTES_X                     is installed
# [INFO] Feature SRC_TCP_PACKETS_X                   is installed
# [INFO] Feature SRC_TCP_BYTES_X                     is installed
# [INFO] Feature SRC_RTP_PACKETS_X_Y                 is installed
# [INFO] Feature SRC_RTP_BYTES_X_Y                   is installed
# [INFO] Feature SRC_LOST_RTP_PACKETS_X_Y            is installed
# [INFO] Feature DST_UDP_PACKETS_X                   is installed
# [INFO] Feature DST_UDP_BYTES_X                     is installed
# [INFO] Feature DST_TCP_PACKETS_X                   is installed
# [INFO] Feature DST_TCP_BYTES_X                     is installed
# [INFO] Feature DST_RTP_PACKETS_X_Y                 is installed
# [INFO] Feature DST_RTP_BYTES_X_Y                   is installed
# [INFO] Feature DST_LOST_RTP_PACKETS_X_Y            is installed
# [INFO] Add pcap listener. (device: veth0), (feature_num: 6), (pcap_filter: )
# [INFO] Feature DST_RTP_BYTES_5000_96 is added listening for device veth0
# [INFO] Feature DST_RTP_BYTES_5000_126 is added listening for device veth0
# [INFO] Feature DST_RTP_BYTES_5016_96 is added listening for device veth0
# [INFO] Feature DST_RTP_BYTES_5016_126 is added listening for device veth0
# [INFO] Feature DST_RTP_BYTES_5030_96 is added listening for device veth0
# [INFO] Feature DST_RTP_BYTES_5030_126 is added listening for device veth0
# [INFO] Mapped var with id 1 is successfully addded to DMAP
# [INFO] FSM: Transitions performed, the actual state is Halt
# [INFO] FSM: Start event is fired, actual state is Halt
# [INFO] Start Records relayer component
# [INFO] Constructing Records relayer component.
# [WARN] (errno: None) Records relayer component is already constructed
# [INFO] Records relayer component is started.
# [INFO] Start Command Interpreter Component
# [INFO] Constructing Command Interpreter Component.
# [INFO] Command Interpreter Component is constructed
# [INFO] Command Interpreter Component is started.
# [INFO] Start PCAP Listener component
# [INFO] Constructing PCAP Listener component.
# [INFO] PCAP Listener component is constructed
# [INFO] PCAP Listener component is started.
# [INFO] FSM: Transitions performed, the actual state is Run
# [INFO] NTRT is going to be terminated 180 sec later
# [INFO] Pcap filter is set to device: veth0
# [INFO] Executing command O sudo ip netns exec ns_mid tc qdisc change dev veth2 parent 1: handle 2: tbf rate 4000kbit burst 400kbit latency 300ms minburst 1540
#
# [INFO] Executing command I MAPPED_VAR_1_4000
#
# [INFO] Mapped var 1 value changed from 0 to 4000
# join subflow 1
# path: 1
# starting server pipeline
# actual state: 3, pending: 4, changeresult: 2
# Pipeline pipeline0 changed state from NULL to READY
# Pipeline pipeline0 changed state from READY to PAUSED
# join subflow 1
# path: 1
# starting server pipeline
# actual state: 3, pending: 4, changeresult: 2
# Pipeline pipeline0 changed state from NULL to READY
# Pipeline pipeline0 changed state from READY to PAUSED
# Pipeline pipeline0 changed state from PAUSED to PLAYING
# Pipeline pipeline0 changed state from PAUSED to PLAYING
# Looking for caps for pt 96 in session 0, have 0
# Returning application/x-rtp, media=(string)video, clock-rate=(int)90000, width=(int)352, height=(int)288, framerate=(fraction)25/1, encoding-name=(string)VP8
# Looking for caps for pt 96 in session 0, have 0
# Returning application/x-rtp, media=(string)video, clock-rate=(int)90000, width=(int)352, height=(int)288, framerate=(fraction)25/1, encoding-name=(string)VP8
# New pad: recv_rtp_src_0_2485037640_96, looking for recv_rtp_src_0_*
# Pipeline pipeline0 changed state from PAUSED to PAUSED
# Linked!
# Pipeline pipeline0 changed state from PAUSED to PAUSED
# Pipeline pipeline0 changed state from PAUSED to PLAYING
# New pad: recv_rtp_src_0_2720420906_96, looking for recv_rtp_src_0_*
# Pipeline pipeline0 changed state from PAUSED to PAUSED
# Linked!
# Pipeline pipeline0 changed state from PAUSED to PAUSED
# Pipeline pipeline0 changed state from PAUSED to PLAYING
# [INFO] Executing command O sudo ip netns exec ns_mid tc qdisc change dev veth2 parent 1: handle 2: tbf rate 2000kbit burst 200kbit latency 300ms minburst 1540
#
# [INFO] Executing command I MAPPED_VAR_1_2000
#
# [INFO] Mapped var 1 value changed from 4000 to 2000
# [INFO] Executing command O sudo ip netns exec ns_mid tc qdisc change dev veth2 parent 1: handle 2: tbf rate 3500kbit burst 350kbit latency 300ms minburst 1540
#
# [INFO] Executing command I MAPPED_VAR_1_3500
#
# [INFO] Mapped var 1 value changed from 2000 to 3500
# [INFO] Executing command O sudo ip netns exec ns_mid tc qdisc change dev veth2 parent 1: handle 2: tbf rate 1000kbit burst 100kbit latency 300ms minburst 1540
#
# [INFO] Executing command I MAPPED_VAR_1_1000
#
# [INFO] Mapped var 1 value changed from 3500 to 1000
# [INFO] Executing command O sudo ip netns exec ns_mid tc qdisc change dev veth2 parent 1: handle 2: tbf rate 2000kbit burst 200kbit latency 300ms minburst 1540
#
# [INFO] Executing command I MAPPED_VAR_1_2000
#
# [INFO] Mapped var 1 value changed from 1000 to 2000
# [INFO] Command interpreter is finished with file scripts2/configs/ntrt_rmcat2.cmds
# [INFO] FSM: Stop event is fired, actual state is Run
# [INFO] STOP Records relayer component.
# [INFO] Destructing Records relayer component.
# [INFO] Records relayer component is destructed.
# [INFO] Records relayer component is stopped.
# [INFO] STOP PCAP Listener component.
#
# Usage:
#  kill [options] <pid> [...]
#
# Options:
#  <pid> [...]            send signal to every <pid> listed
#  -<signal>, -s, --signal <signal>
#                         specify the <signal> to be sent
#  -l, --list=[<signal>]  list all signal names, or convert one to a name
#  -L, --table            list all signal names in a nice table
#
#  -h, --help     display this help and exit
#  -V, --version  output version information and exit
#
# For more details see kill(1).
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-93-448f7ec8a1e1> in <module>()
#      25     for y in range(range_bgn, range_end):
#      26         get_ipython().system('cd ..;cd ..; scripts2/runs/rmcat2.sh -s $owd ')
# ---> 27         save_measurement(owd, container, y)
#      28         plot_snd_throughputs(owd, container, duration, range_, flownum, label, legend, y)
#      29
#
# <ipython-input-82-d09e874aeb9e> in save_measurement(owd, container, counter)
#      13         src_path = "../saves/" + src_file
#      14         dst_path = save_directory + dst_file
# ---> 15         copyfile(src_path, dst_path)
#
# /usr/lib/python3.4/shutil.py in copyfile(src, dst, follow_symlinks)
#     106         os.symlink(os.readlink(src), dst)
#     107     else:
# --> 108         with open(src, 'rb') as fsrc:
#     109             with open(dst, 'wb') as fdst:
#     110                 copyfileobj(fsrc, fdst)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../saves/veth0_stats.csv'

# %%
#RMCAT3 Test

container = "rmcat3"
veth0_str = "veth0_stats"
veth3_str = "veth3_stats"
duration  = 140
range_    = 5000
flownum   = 1

range_bgn = 3
range_end = 4
plays     = [0,1,0] 

owds      = [50,150,300]
labels    = [True,False,False]
legends   = [False,False,True]

for x in range(0,3) :
    
    if(plays[x] == 0) :
        continue;
        
    owd    = owds[x]
    label  = labels[x]
    legend = legends[x]
    
    for y in range(range_bgn, range_end):
        # !cd ..;cd ..; scripts2/runs/rmcat2.sh -s $owd 
        save_measurement(owd, container, y)
        plot_snd_throughputs(owd, container, duration, range_, flownum, label, legend, y, veth0_str)
        plot_snd_throughputs(owd, container, duration, range_, flownum, label, legend, y, veth3_str)
    
    eval_measurements(owd, container, duration * 10)
# Out:
# 150
# 300
